# %% [markdown]
# <a href="https://colab.research.google.com/github/Vigash14120/AI-by-INTEL/blob/main/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('/content/ipl-matches.csv')

# %%
ipl = pd.read_csv('/content/ipl-matches.csv')

# %%
##shape
ipl.shape
# Out:
# (950, 20)

# %%
##size
ipl.size
# Out:
# 19000

# %%
#head()
#tail
#sample---random row
ipl.head(7)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
# 5  1304115     Mumbai  2022-05-21   2022           69
# 6  1304114     Mumbai  2022-05-20   2022           68
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
# 5               Delhi Capitals        Mumbai Indians
# 6          Chennai Super Kings      Rajasthan Royals
#
#                               Venue            TossWinner TossDecision  \
# ...

# %%
##accessing single columns
ipl['City']
# Out:
# 0       Ahmedabad
# 1       Ahmedabad
# 2         Kolkata
# 3         Kolkata
# 4          Mumbai
#           ...
# 945       Kolkata
# 946        Mumbai
# 947         Delhi
# 948    Chandigarh
# 949     Bangalore
# Name: City, Length: 950, dtype: object

# %%
#info()
#isnull()
#dropna()
#inplace
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
#isnull()
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
ipl.isnull().mean()*100
##Misssing percentage
# Out:
# ID                  0.000000
# City                5.368421
# Date                0.000000
# Season              0.000000
# MatchNumber         0.000000
# Team1               0.000000
# Team2               0.000000
# Venue               0.000000
# TossWinner          0.000000
# TossDecision        0.000000
# SuperOver           0.421053
# WinningTeam         0.421053
# WonBy               0.000000
# Margin              1.894737
# method             98.000000
# Player_of_Match     0.421053
# Team1Players        0.000000
# Team2Players        0.000000
# Umpire1             0.000000
# Umpire2             0.000000
# dtype: float64

# %%
####dropping column
ipl.drop(columns=['method'],inplace= True )

# %%
#inplace true for permenant chanege in the dataframe
ipl.sample()
# Out:
#          ID    City        Date Season MatchNumber                 Team1  \
# 37  1304083  Mumbai  2022-04-24   2022          37  Lucknow Super Giants
#
#              Team2                     Venue      TossWinner TossDecision  \
# 37  Mumbai Indians  Wankhede Stadium, Mumbai  Mumbai Indians        field
#
#    SuperOver           WinningTeam WonBy  Margin Player_of_Match  \
# 37         N  Lucknow Super Giants  Runs    36.0        KL Rahul
#
#                                          Team1Players  \
# 37  ['Q de Kock', 'KL Rahul', 'MK Pandey', 'MP Sto...
#
#                                          Team2Players    Umpire1     Umpire2
# 37  ['Ishan Kishan', 'RG Sharma', 'D Brevis', 'SA ...  M Erasmus  HAS Khalid

# %%
##make data clean by dropping null values
ipl.dropna(inplace = True)

# %%
##all null values have been dropped
ipl.isnull().sum()
# Out:
# ID                 0
# City               0
# Date               0
# Season             0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# SuperOver          0
# WinningTeam        0
# WonBy              0
# Margin             0
# Player_of_Match    0
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# dtype: int64

# %%
##lambda
#apply
a = lambda x: x**2
a(9)
# Out:
# 81
